# %%
import numpy as np

# %%
m=np.loadtxt(r"C:\\Users\\Admin\\OneDrive\\Documents\\Programming\\Py_prog\\winequality-red.csv",delimiter=';',skiprows=1)

print(m)
type(m)
# Out:
# [[ 7.4    0.7    0.    ...  0.56   9.4    5.   ]
#  [ 7.8    0.88   0.    ...  0.68   9.8    5.   ]
#  [ 7.8    0.76   0.04  ...  0.65   9.8    5.   ]
#  ...
#  [ 6.3    0.51   0.13  ...  0.75  11.     6.   ]
#  [ 5.9    0.645  0.12  ...  0.71  10.2    5.   ]
#  [ 6.     0.31   0.47  ...  0.66  11.     6.   ]]
# numpy.ndarray

# %%
wines=m.astype('float64')
wines[2,6]=10
new=wines[:,9]
new[:]=666
new.astype(int)
wines[:,-2]*wines[:,-1]
# Out:
# array([47., 49., 49., ..., 66., 51., 66.])

# %%
sum(wines[0])
# Out:
# 739.9838

# %%
import pandas as pd

iris=pd.read_csv('C:\\Users\\Admin\\Downloads\\iris.csv')

# %%
print(iris.describe())

print(iris.info())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
# ...

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
movies=pd.read_csv('C:\\Users\\Admin\\Downloads\\National_Universities_Rankings (1).csv')
movies
# Out:
#      index                                      Name             Location  \
# 0        0                      Princeton University        Princeton, NJ
# 1        1                        Harvard University        Cambridge, MA
# 2        2                     University of Chicago          Chicago, IL
# 3        3                           Yale University        New Haven, CT
# 4        4                       Columbia University         New York, NY
# ..     ...                                       ...                  ...
# 226    226    University of Massachusetts--Dartmouth  North Dartmouth, MA
# 227    227         University of Missouri--St. Louis        St. Louis, MO
# 228    228  University of North Carolina--Greensboro       Greensboro, NC
# 229    229        University of Southern Mississippi      Hattiesburg, MS
# 230    230                     Utah State University            Logan, UT
#
#      Rank                                        Description Tuition and fees  \
# ...

# %%
movies['state']=movies['Location'].apply(lambda x:x.split(',')[-1])
movies['city']=movies['Location'].apply(lambda x:x.split(',')[0])
movies.groupby(['state','city'])[['Name']].first()
# Out:
#                                                Name
# state city
#  AK   Fairbanks     University of Alaska--Fairbanks
#  AL   Auburn                      Auburn University
#       Birmingham  University of Alabama--Birmingham
#       Huntsville  University of Alabama--Huntsville
#       Tuscaloosa              University of Alabama
# ...                                             ...
#  WA   Seattle              University of Washington
#  WI   Madison      University of Wisconsin--Madison
#       Milwaukee                Marquette University
#  WV   Morgantown           West Virginia University
#  WY   Laramie                 University of Wyoming
#
# [192 rows x 1 columns]

# %%
movies[movies['Rank']<50].groupby('state')['Name'].count()
# Out:
# state
#  CA    9
#  CT    1
#  DC    1
#  FL    1
#  GA    2
#  IL    3
#  IN    1
#  LA    1
#  MA    7
#  MD    1
#  MI    1
#  MO    1
#  NC    3
#  NH    1
#  NJ    1
#  NY    5
#  OH    1
#  PA    3
#  RI    1
#  TN    1
#  TX    1
#  VA    2
#  WI    1
# Name: Name, dtype: int64

# %%
movies[(movies['Tuition and fees']>'$15,000') & (movies['Rank'].between(120,170))]

movies.groupby(['Name','city'])['city'].apply(lambda x:x.count()>1)

# movies['Rank'].corr(movies['Undergrad Enrollment'])
movies
# Out:
#      index                                      Name             Location  \
# 0        0                      Princeton University        Princeton, NJ
# 1        1                        Harvard University        Cambridge, MA
# 2        2                     University of Chicago          Chicago, IL
# 3        3                           Yale University        New Haven, CT
# 4        4                       Columbia University         New York, NY
# ..     ...                                       ...                  ...
# 226    226    University of Massachusetts--Dartmouth  North Dartmouth, MA
# 227    227         University of Missouri--St. Louis        St. Louis, MO
# 228    228  University of North Carolina--Greensboro       Greensboro, NC
# 229    229        University of Southern Mississippi      Hattiesburg, MS
# 230    230                     Utah State University            Logan, UT
#
#      Rank                                        Description Tuition and fees  \
# ...

# %%
adi=pd.read_excel("C:\\Users\\Admin\\Downloads\\Adidas_US_Sales_Datasets_1_.xlsx")
adi
# Out:
#       Unnamed: 0     Retailer  Retailer ID Invoice Date     Region  \
# 0            NaN  Foot Locker      1185732   2020-01-01  Northeast
# 1            NaN  Foot Locker      1185732   2020-01-02  Northeast
# 2            NaN  Foot Locker      1185732   2020-01-03  Northeast
# 3            NaN  Foot Locker      1185732   2020-01-04  Northeast
# 4            NaN  Foot Locker      1185732   2020-01-05  Northeast
# ...          ...          ...          ...          ...        ...
# 9643         NaN  Foot Locker      1185732   2021-01-24  Northeast
# 9644         NaN  Foot Locker      1185732   2021-01-24  Northeast
# 9645         NaN  Foot Locker      1185732   2021-02-22  Northeast
# 9646         NaN  Foot Locker      1185732   2021-02-22  Northeast
# 9647         NaN  Foot Locker      1185732   2021-02-22  Northeast
#
#               State        City                    Product  Price per Unit  \
# 0          New York    New York      Men's Street Footwear            50.0
# ...

# %%
adi.groupby(['Product',pd.Grouper(key="Invoice Date",axis=0,freq='m')])[['Total Sales','Operating Profit']].sum().diff()
# Out:
#                                       Total Sales  Operating Profit
# Product                 Invoice Date
# Men's Apparel           2020-01-31            NaN               NaN
#                         2020-02-29        -3721.0         136817.54
#                         2020-03-31       -60174.0        -102899.19
#                         2020-04-30      1565132.0         674450.60
#                         2020-05-31      -796648.0        -356417.82
# ...                                           ...               ...
# Women's Street Footwear 2021-08-31       141617.0          89724.80
#                         2021-09-30     -2134196.0        -431973.05
#                         2021-10-31     -1394463.0        -642288.21
#                         2021-11-30       163718.0        -116075.74
#                         2021-12-31      3281479.0        1182520.74
#
# [144 rows x 2 columns]

# %%
# pd.Series([1,2,3,4],index=[1,2,3,4])

d={1:2,2:3,3:4}
m=pd.Series([1,2,3])
n=pd.Series([3,7])
pd.concat([m,n],axis=1)
# Out:
#    0    1
# 0  1  3.0
# 1  2  7.0
# 2  3  NaN

# %%
arr1 = np.array([[1, 2], [5, 6]])
arr2 = np.array([[7, 8], [3,4]])
print(arr1.sum(axis=0),arr1.sum(axis=1))
np.concatenate([arr1,arr2],axis=1)
# Out:
# [6 8] [ 3 11]
# array([[1, 2, 7, 8],
#        [5, 6, 3, 4]])

# %%
# np.isnan(arr1)
arr1.astype(int)

np.nan_to_num(3)
n=np.array([1,2,3,4,5])
np.cumsum(n)

adi.value_sort()
# print(adi.columns.size,movies.columns.size)
# pd.concat([adi,movies],axis=0)
# pd.concat([adi,movies],axis=0).columns.size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10224/4036976940.py in <module>
#       6 np.cumsum(n)
#       7
# ----> 8 adi.values_sort('Retailer')
#       9 # print(adi.columns.size,movies.columns.size)
#      10 # pd.concat([adi,movies],axis=0)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'values_sort'
